# %%
import pandas as pd

pd.options.display.max_columns = 999

# %%
df = pd.read_csv('data/Business_Licenses_-_Current_Active.csv')

# %% [markdown]
# ## EDA

# %%
list(df['ZIP CODE'].unique())
# Out:
# ['60623',
#  '60611',
#  '60610',
#  '60618',
#  '60628',
#  '46038',
#  '60153',
#  '60614',
#  '60620',
#  '60617',
#  '60608',
#  '60606',
#  '60601',
#  '60126',
#  '60440',
#  '01606',
#  '60018',
#  '60093',
#  '60527',
#  '60143',
#  '60007',
#  '60025',
#  '46375',
#  '60446',
#  '60521',
#  '60411',
#  '60487',
#  '60193',
#  '60162',
#  '60515',
#  '60714',
#  '60031',
#  '60448',
#  '60804',
#  '60062',
#  '60191',
#  '60467',
#  '47906',
#  '60712',
#  '49417',
#  '46311',
#  '60603',
#  '60016',
#  '60605',
#  '60666',
#  '60827',
#  '60077',
#  '53144',
#  '60513',
#  '60419',
#  '78750',
#  '60030',
#  '60476',
#  '60452',
#  '60612',
#  '60634',
#  '60647',
#  '60070',
#  '60651',
#  '60004',
#  '60609',
#  '60622',
#  '60438',
#  '60302',
#  '60654',
#  '60639',
#  '60657',
#  '60607',
#  '60076',
#  '60644',
#  '60459',
#  '60185',
#  '60652',
#  '60659',
#  '60616',
#  '60640',
#  '60642',
#  '60630',
#  '60649',
#  '60656',
#  '60660',
#  '60464',
#  '60008',
# ...

# %%
df['LICENSE DESCRIPTION'].value_counts()
# Out:
# Limited Business License                               21432
# Retail Food Establishment                              11729
# Regulated Business License                              9597
# Consumption on Premises - Incidental Activity           2764
# Tobacco                                                 2218
# Motor Vehicle Services License                          1710
# Peddler License                                         1568
# Package Goods                                           1142
# Pharmaceutical Representative                           1094
# Tavern                                                   871
# Children's Services Facility License                     870
# Manufacturing Establishments                             855
# Public Place of Amusement                                763
# Commercial Garage                                        638
# Outdoor Patio                                            621
# ...

# %%
coffee_df = df[df['BUSINESS ACTIVITY'].str.contains('[cC][oO][fF][fF][eE][eE]')==True]
#

# %%
coffee_df['BUSINESS ACTIVITY'].value_counts()
# Out:
# Preparation of Food, Coffee or Drinks                                                                                                                                                                                                                                                                      45
# Retail Sales of Perishable Foods | Preparation of Food, Coffee or Drinks                                                                                                                                                                                                                                   20
# Retail Sales of General Merchandise and Non-Perishable Food | Retail Sales of Perishable Foods | Preparation of Food, Coffee or Drinks                                                                                                                                                                     18
# ...

# %%
starbucks = df[df['DOING BUSINESS AS NAME'].str.contains('[S][T][A][R][B][U][C]')==True]

# %%
starbucks.head()
# Out:
#                     ID  LICENSE ID  ACCOUNT NUMBER  SITE NUMBER  \
# 477   2506134-20170215     2506134           63414          181
# 978   2506949-20170227     2506949           63414          183
# 1945  2506946-20170310     2506946           63414          182
# 2201  2500982-20170315     2500982           63414          180
# 3834  1422751-20170416     2513180           63414           99
#
#                  LEGAL NAME   DOING BUSINESS AS NAME  \
# 477   STARBUCKS CORPORATION  STARBUCKS COFFEE #48615
# 978   STARBUCKS CORPORATION  STARBUCKS COFFEE #47593
# 1945  STARBUCKS CORPORATION  STARBUCKS COFFEE #10506
# 2201  STARBUCKS CORPORATION  STARBUCKS COFFEE #25092
# 3834  STARBUCKS CORPORATION   STARBUCKS COFFEE #2929
#
#                         ADDRESS     CITY STATE ZIP CODE  WARD  PRECINCT  \
# 477   1601 W IRVING PARK RD 1ST  CHICAGO    IL    60613  47.0      25.0
# 978    6332 N NORTHWEST HWY 1ST  CHICAGO    IL    60631  41.0      16.0
# ...

# %%
starbucks.sort_values('SITE NUMBER')
# Out:
#                      ID  LICENSE ID  ACCOUNT NUMBER  SITE NUMBER  \
# 34240  2138252-20180516     2587208          369504            1
# 13310  2555480-20170926     2555480          421040            1
# 29203  1932196-20180416     2581539          337031            1
# 60613  2157525-20180516     2587209          369504            2
# 44755  2464644-20180616     2594249          406287            2
# 42115  2570066-20180806     2570066          423641            2
# 3843     23011-20170416     2513110           63414            2
# 34236  2142220-20180516     2587210          369504            3
# 16964    23013-20170416     2513111           63414            3
# 53528  2363762-20190116     2635619          394557            4
# 34213  2147404-20180516     2587211          369504            4
# 3932     23015-20170416     2513112           63414            4
# 3965     23017-20170416     2513113           63414            5
# ...

# %%
starbucks.count()
# Out:
# ID                                   146
# LICENSE ID                           146
# ACCOUNT NUMBER                       146
# SITE NUMBER                          146
# LEGAL NAME                           146
# DOING BUSINESS AS NAME               146
# ADDRESS                              146
# CITY                                 146
# STATE                                146
# ZIP CODE                             146
# WARD                                 146
# PRECINCT                             146
# WARD PRECINCT                        146
# POLICE DISTRICT                      146
# LICENSE CODE                         146
# LICENSE DESCRIPTION                  146
# BUSINESS ACTIVITY ID                 146
# BUSINESS ACTIVITY                    146
# LICENSE NUMBER                       146
# APPLICATION TYPE                     146
# APPLICATION CREATED DATE              10
# APPLICATION REQUIREMENTS COMPLETE    146
# PAYMENT DATE                         146
# ...

# %%
CREATE TABLE IF NOT EXISTS CoffeeShops (
    licenseID varchar(500) NOT NULL
    businessName varchar(500) NOT NULL,
    rating varchar(500) DEFAULT NULL,
    reviews varchar(500) DEFAULT NULL
    address varchar(500) NOT NULL,
    latitude int NOT NULL,
    longitude int NOT NULL,
    PRIMARY KEY (licenseID)
);
