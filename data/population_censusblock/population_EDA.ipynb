# %%
import pandas as pd

# %%
df_pop = pd.read_csv('Population_by_2010_Census_Block.csv')

# %%
df_pop.head()
# Out:
#    CENSUS BLOCK  CENSUS BLOCK FULL  TOTAL POPULATION
# 0     101001000    170310101001000               128
# 1     101001001    170310101001001                71
# 2     101001002    170310101001002                45
# 3     101001003    170310101001003               335
# 4     101002000    170310101002000               152
